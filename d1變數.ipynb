# %% [markdown]
# <a href="https://colab.research.google.com/github/huangqianpei0-cloud/promming/blob/main/d1%E8%AE%8A%E6%95%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=4

# %%
type(a)
# Out:
# int

# %%
b='wasd'

# %%
type(b)
# Out:
# str

# %%
y=True

# %%
type(y)
# Out:
# bool

# %%
r=2.96

# %%
type(r)
# Out:
# float
